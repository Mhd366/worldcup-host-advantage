# %% [markdown]
# FIFA World Cup: Host Advantage Analysis & Saudi 2034 Outlook

# %% [markdown]
# 1. Introduction & Problem Definition

# %% [markdown]
# 2. Data Loading & Structure

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

df = pd.read_csv('../data/raw/worldcup_matches.csv')
df.head()
# Out:
#    home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0  Argentina    France           3      3.3           4.0           3
# 1    Croatia   Morocco           2      0.7           NaN           1
# 2     France   Morocco           2      2.0           NaN           0
# 3  Argentina   Croatia           3      2.3           NaN           0
# 4    Morocco  Portugal           1      1.4           NaN           0
#
#    away_xg  away_penalty      home_manager  home_captain      away_manager  \
# 0      2.2           2.0    Lionel Scaloni  Lionel Messi  Didier Deschamps
# 1      1.2           NaN      Zlatko Dalić   Luka Modrić   Hoalid Regragui
# 2      0.9           NaN  Didier Deschamps   Hugo Lloris   Hoalid Regragui
# 3      0.5           NaN    Lionel Scaloni  Lionel Messi      Zlatko Dalić
# 4      0.9           NaN   Hoalid Regragui  Romain Saïss   Fernando Santos
#
#    away_captain  Attendance                                Venue  \
# 0   Hugo Lloris       88966        Lusail Iconic Stadium, Lusail
# 1  Hakim Ziyech       44137  Khalifa International Stadium, Doha
# 2  Romain Saïss       68294             Al Bayt Stadium, Al Khor
# 3   Luka Modrić       88966        Lusail Iconic Stadium, Lusail
# 4          Pepe       44198      Al Thumama Stadium, ath-Thumāma
#
#                                            Officials              Round  \
# 0  Szymon Marciniak (Referee) · Paweł Sokolnicki ...              Final
# 1  Abdulrahman Ibrahim Al Jassim (Referee) · Tale...  Third-place match
# 2  César Arturo Ramos (Referee) · Alberto Morín (...        Semi-finals
# 3  Daniele Orsato (Referee) · Ciro Carbone (AR1) ...        Semi-finals
# 4  Facundo Tello (Referee) · Ezequiel Brailovsky ...     Quarter-finals
#
#          Date        Score                        Referee  \
# 0  2022-12-18  (4) 3–3 (2)               Szymon Marciniak
# 1  2022-12-17          2–1  Abdulrahman Ibrahim Al Jassim
# 2  2022-12-14          2–0             César Arturo Ramos
# 3  2022-12-13          3–0                 Daniele Orsato
# 4  2022-12-10          1–0                  Facundo Tello
#
#                                                Notes   Host  Year  \
# 0  Argentina won on penalty kicks following extra...  Qatar  2022
# 1                                                NaN  Qatar  2022
# 2                                                NaN  Qatar  2022
# 3                                                NaN  Qatar  2022
# 4                                                NaN  Qatar  2022
#
#                                    home_goal           away_goal  \
# 0     Ángel Di María · 36|Lionel Messi · 108  Kylian Mbappé · 81
# 1       Joško Gvardiol · 7|Mislav Oršić · 42     Achraf Dari · 9
# 2  Theo Hernández · 5|Randal Kolo Muani · 79                 NaN
# 3    Julián Álvarez · 39|Julián Álvarez · 69                 NaN
# 4                     Youssef En-Nesyri · 42                 NaN
#
#                                       home_goal_long  \
# 0  ['36&rsquor;|2:0|Ángel Di María|Assist:|Alexis...
# 1  ['7&rsquor;|1:0|Joško Gvardiol|Assist:|Ivan Pe...
# 2  ['5&rsquor;|1:0|Theo Hernández', '79&rsquor;|2...
# 3  ['39&rsquor;|2:0|Julián Álvarez', '69&rsquor;|...
# 4  ['42&rsquor;|1:0|Youssef En-Nesyri|Assist:|Yah...
#
#                                       away_goal_long home_own_goal  \
# 0  ['81&rsquor;|2:2|Kylian Mbappé|Assist:|Marcus ...           NaN
# 1                      ['9&rsquor;|1:1|Achraf Dari']           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
#
#   away_own_goal      home_penalty_goal  \
# 0           NaN  Lionel Messi (P) · 23
# 1           NaN                    NaN
# 2           NaN                    NaN
# 3           NaN  Lionel Messi (P) · 34
# 4           NaN                    NaN
#
#                                 away_penalty_goal home_penalty_miss_long  \
# 0  Kylian Mbappé (P) · 80|Kylian Mbappé (P) · 118                    NaN
# 1                                             NaN                    NaN
# 2                                             NaN                    NaN
# 3                                             NaN                    NaN
# 4                                             NaN                    NaN
#
#   away_penalty_miss_long                    home_penalty_shootout_goal_long  \
# 0                    NaN  ['2|1:1|Lionel Messi', '4|2:1|Paulo Dybala', '...
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
#
#                      away_penalty_shootout_goal_long  \
# 0  ['1|0:1|Kylian Mbappé', '7|3:2|Randal Kolo Mua...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   home_penalty_shootout_miss_long  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#                      away_penalty_shootout_miss_long home_red_card  \
# 0  ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
#
#   away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0           NaN                    NaN                  NaN
# 1           NaN                    NaN                  NaN
# 2           NaN                    NaN                  NaN
# 3           NaN                    NaN                  NaN
# 4           NaN  Walid Cheddira · 90+3                  NaN
#
#                                home_yellow_card_long  \
# 0  ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                NaN
# 2                                                NaN
# 3  ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4  ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
#
#                                away_yellow_card_long  \
# 0  ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1  ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                  ['27&rsquor;|1:0|Sofiane Boufal']
# 3  ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                         ['87&rsquor;|1:0|Vitinha']
#
#                              home_substitute_in_long  \
# 0  ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1  ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2  ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3  ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4  ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
#
#                              away_substitute_in_long
# 0  ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1  ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2  ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3  ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4  ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...

# %% [markdown]
# **964 matches** covering every World Cup from 1930 to 2022, one row per match. The `Host` column is key — it lets us directly compare host-nation performance vs. everyone else.

# %%
df.shape
# Out:
# (964, 44)

# %% [markdown]
# 964 rows × 44 columns — one row per match, far more detail than we need for our research question.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 964 entries, 0 to 963
# Data columns (total 44 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   home_team                        964 non-null    str
#  1   away_team                        964 non-null    str
#  2   home_score                       964 non-null    int64
#  3   home_xg                          128 non-null    float64
#  4   home_penalty                     35 non-null     float64
#  5   away_score                       964 non-null    int64
#  6   away_xg                          128 non-null    float64
#  7   away_penalty                     35 non-null     float64
#  8   home_manager                     964 non-null    str
#  9   home_captain                     644 non-null    str
#  10  away_manager                     964 non-null    str
#  11  away_captain                     644 non-null    str
#  12  Attendance                       964 non-null    int64
#  13  Venue                            964 non-null    str
#  14  Officials                        709 non-null    str
#  15  Round                            964 non-null    str
#  16  Date                             964 non-null    str
#  17  Score                            964 non-null    str
#  18  Referee                          709 non-null    str
#  19  Notes                            73 non-null     str
#  20  Host                             964 non-null    str
#  21  Year                             964 non-null    int64
#  22  home_goal                        718 non-null    str
#  23  away_goal                        571 non-null    str
#  24  home_goal_long                   718 non-null    str
#  25  away_goal_long                   571 non-null    str
#  26  home_own_goal                    39 non-null     str
#  27  away_own_goal                    17 non-null     str
#  28  home_penalty_goal                116 non-null    str
#  29  away_penalty_goal                84 non-null     str
#  30  home_penalty_miss_long           6 non-null      str
#  31  away_penalty_miss_long           9 non-null      str
#  32  home_penalty_shootout_goal_long  34 non-null     str
#  33  away_penalty_shootout_goal_long  34 non-null     str
#  34  home_penalty_shootout_miss_long  24 non-null     str
#  35  away_penalty_shootout_miss_long  30 non-null     str
#  36  home_red_card                    51 non-null     str
#  37  away_red_card                    54 non-null     str
#  38  home_yellow_red_card             23 non-null     str
#  39  away_yellow_red_card             31 non-null     str
#  40  home_yellow_card_long            621 non-null    str
#  41  away_yellow_card_long            627 non-null    str
#  42  home_substitute_in_long          740 non-null    str
#  43  away_substitute_in_long          747 non-null    str
# dtypes: float64(4), int64(4), str(36)
# memory usage: 965.1 KB

# %% [markdown]
# A mix of numeric (scores, attendance), categorical (teams, round, host), and raw text event logs. Two types need fixing: `Date` should be datetime and `Attendance` numeric.

# %%
df.describe()
# Out:
#        home_score     home_xg  home_penalty  away_score     away_xg  \
# count  964.000000  128.000000     35.000000  964.000000  128.000000
# mean     1.776971    1.435938      3.285714    1.044606    1.192187
# std      1.596676    0.860391      1.226459    1.071233    0.809258
# min      0.000000    0.100000      0.000000    0.000000    0.000000
# 25%      1.000000    0.800000      3.000000    0.000000    0.600000
# 50%      1.000000    1.300000      3.000000    1.000000    1.000000
# 75%      3.000000    1.925000      4.000000    2.000000    1.525000
# max     10.000000    5.200000      5.000000    7.000000    5.700000
#
#        away_penalty     Attendance         Year
# count     35.000000     964.000000   964.000000
# mean       3.057143   45693.374481  1989.244813
# std        1.136115   22704.131689    24.014409
# min        0.000000    2000.000000  1930.000000
# 25%        2.000000   31800.000000  1974.000000
# 50%        3.000000   42725.000000  1994.000000
# 75%        4.000000   60984.500000  2010.000000
# max        5.000000  173850.000000  2022.000000

# %% [markdown]
# Score statistics look plausible (no negative or absurd values). Attendance varies widely — from a few thousand in early eras to ~89,000 in modern finals.

# %%
df.isnull().sum()
# Out:
# home_team                            0
# away_team                            0
# home_score                           0
# home_xg                            836
# home_penalty                       929
# away_score                           0
# away_xg                            836
# away_penalty                       929
# home_manager                         0
# home_captain                       320
# away_manager                         0
# away_captain                       320
# Attendance                           0
# Venue                                0
# Officials                          255
# Round                                0
# Date                                 0
# Score                                0
# Referee                            255
# Notes                              891
# Host                                 0
# Year                                 0
# home_goal                          246
# away_goal                          393
# home_goal_long                     246
# away_goal_long                     393
# home_own_goal                      925
# away_own_goal                      947
# home_penalty_goal                  848
# away_penalty_goal                  880
# home_penalty_miss_long             958
# away_penalty_miss_long             955
# home_penalty_shootout_goal_long    930
# away_penalty_shootout_goal_long    930
# home_penalty_shootout_miss_long    940
# away_penalty_shootout_miss_long    934
# home_red_card                      913
# away_red_card                      910
# home_yellow_red_card               941
# away_yellow_red_card               933
# home_yellow_card_long              343
# away_yellow_card_long              337
# home_substitute_in_long            224
# away_substitute_in_long            217
# dtype: int64

# %% [markdown]
# Missing values are **structural, not errors**: xG only exists since 2018, penalty columns are empty unless a shootout occurred, and referee records are incomplete in early eras. All core columns (teams, scores, host, year) are 100% complete.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No duplicate rows — the dataset is ready for cleaning and feature engineering.

# %% [markdown]
# 3. Data Cleaning

# %%
df = pd.read_csv('../data/raw/worldcup_matches.csv')

# --- 3.1 Keep only analysis-relevant columns ---
keep_cols = ['Year', 'Host', 'Date', 'Round', 'Venue', 'Attendance',
             'home_team', 'away_team', 'home_score', 'away_score',
             'home_penalty', 'away_penalty',
             'home_red_card', 'away_red_card']
df = df[keep_cols].copy()

# %%
# --- 3.2 Rename to consistent snake_case ---
df.columns = df.columns.str.lower()

# %%
# --- 3.3 Convert data types ---
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df['attendance'] = pd.to_numeric(df['attendance'], errors='coerce')

# %%
# --- 3.4 Handle missing values (with justification!) ---
# penalties: NaN means "no shootout" -> flag it, then drop raw cols
df['went_to_shootout'] = df['home_penalty'].notna().astype(int)
# red cards: NaN means "no red card" -> count of names, 0 if NaN
df['home_red_cards'] = df['home_red_card'].fillna('').apply(
    lambda x: 0 if x == '' else len(str(x).split('|')))
df['away_red_cards'] = df['away_red_card'].fillna('').apply(
    lambda x: 0 if x == '' else len(str(x).split('|')))
df = df.drop(columns=['home_penalty', 'away_penalty',
                      'home_red_card', 'away_red_card'])

# %%
# --- 3.5 Harmonize historical country names ---
name_map = {'West Germany': 'Germany', 'FR Yugoslavia': 'Serbia',
            'Yugoslavia': 'Serbia', 'Soviet Union': 'Russia',
            'Czechoslovakia': 'Czech Republic', 'Dutch East Indies': 'Indonesia'}
for col in ['home_team', 'away_team', 'host']:
    df[col] = df[col].replace(name_map)

# %%
# --- 3.6 Feature engineering (قلب المشروع) ---
df['total_goals'] = df['home_score'] + df['away_score']
df['result'] = np.select(
    [df['home_score'] > df['away_score'],
     df['home_score'] < df['away_score']],
    ['home_win', 'away_win'], default='draw')
# هل أحد الطرفين هو المستضيف؟
df['host_playing'] = ((df['home_team'] == df['host']) |
                      (df['away_team'] == df['host'])).astype(int)
df['host_won'] = np.where(df['host_playing'] == 1,
    ((df['home_team'] == df['host']) & (df['result'] == 'home_win')) |
    ((df['away_team'] == df['host']) & (df['result'] == 'away_win')), np.nan)

# %%
# --- 3.7 Sanity checks ---
print(df.shape)
print(df.isnull().sum())
print(df['host_playing'].sum(), "مباراة لعبها المستضيف")
# Out:
# (964, 17)
# year                  0
# host                  0
# date                  0
# round                 0
# venue                 0
# attendance            0
# home_team             0
# away_team             0
# home_score            0
# away_score            0
# went_to_shootout      0
# home_red_cards        0
# away_red_cards        0
# total_goals           0
# result                0
# host_playing          0
# host_won            854
# dtype: int64
# 110 مباراة لعبها المستضيف

# %%
# --- 3.8 Save ---
df.to_csv('../data/clean/clean_data.csv', index=False)
